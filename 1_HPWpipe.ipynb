# %%
"""This script will concatenate uvf5 files in time based on certain parameters."""
# Python Standard Library Packages
import os
import glob
import argparse

# Community Developed Packages
import numpy as np
import astropy.units as u
import astropy.coordinates as aco

# HERA Collaboration Packages
from pyuvdata import UVData

# %%
parser = argparse.ArgumentParser()
parser.add_argument(
    '-F',
    '--files',
    help='Designate the hdf5 files to be concatenated in time.',
    nargs='*',
    required=True)
parser.add_argument(
    '-P',
    '--pols',
    help='Designate which polarizations to analyze (e.g.: "xx xy yx yy").',
    nargs='*',
    required=True)
parser.add_argument(
    '-D',
    '--day',
    help='Designate which JD the hdf5 files come from.',
    required=True)
parser.add_argument(
    '-E',
    '--ext',
    help='Designate which file extension (i.e., uvOCRS) the designated hdf5 files are.',
    required=True)
parser.add_argument(
    '-L',
    '--LSTrng',
    help='Designate which LST in hours that will be analyzed (e.g.: "6.0 7.0").',
    type=float,
    nargs=2,
    required=True)
parser.add_argument(
    '-X',
    '--xants',
    help='Designate which antenna numbers that should be excluded from analysis (e.g.: "0 50 98").',
    type=int,
    nargs='*',
    default=list())
parser.add_argument(
    '-S',
    '--savepath',
    help='Designate the path where the new hdf5 files will be saved.',
    required=True)
# Out:
# _StoreAction(option_strings=['-S', '--savepath'], dest='savepath', nargs=None, const=None, default=None, type=None, choices=None, help='Designate the path where the new hdf5 files will be saved.', metavar=None)

# %%
"""Uncomment this code when running as .py:"""
# args = parser.parse_args()
# files = np.array(sorted(args.files))
# Out:
# 'Uncomment this code when running as .py:'

# %%
"""Uncomment this code when running as .ipynb:"""
args = parser.parse_args(
    "-F /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.?????.??.HH.uvcRP \
    -P xx xy yx yy\
    -D 2457548 \
    -E uvcRP \
    -L 10.5 23 \
    -X 22 43 80 81 \
    -S /data4/paper/fox/HERA19Golden/".split())
files = sorted(glob.glob(args.files[0]))

# %%
"""Formatting command line arguments:"""
pols = sorted(args.pols)
day = args.day
ext = args.ext
LSTrng = args.LSTrng
xants = sorted(args.xants)
savepath = os.path.join(args.savepath, '{ext}/{day}/LSThrs_{LST0}_to_{LSTf}'.format(
    ext=ext,
    day=day,
    LST0=LSTrng[0],
    LSTf=LSTrng[-1]))
os.system('mkdir -p {}'.format(savepath))
print 'Saving files to:\n{}'.format(savepath)
print 'Polarizations: {}'.format(pols)
print 'Extension: {}'.format(ext)
print 'LST Range: Hour {} to Hour {} '.format(LSTrng[0], LSTrng[-1])
print 'Excluded Antennae: {}'.format(xants)
# Out:
# Saving files to:
# /data4/paper/fox/HERA19Golden/uvcRP/2457548/LSThrs_10.5_to_23.0
# Polarizations: ['xx', 'xy', 'yx', 'yy']
# Extension: uvcRP
# LST Range: Hour 10.5 to Hour 23.0
# Excluded Antennae: [22, 43, 80, 81]

# %%
"""Looping through each polarization, finding correct files based on given LST range:"""
pol_files = {pol: sorted([file for file in files if pol in file]) for pol in pols}
for pol, dfiles in pol_files.items():
    print pol
    
    # Finding the correct files based on the provided LST range
    uvd = UVData()
    files = []
    times = []
    for dfile in dfiles:
        print dfile
        # uvd.read_uvh5(dfile, read_data=False)
        uvd.read_miriad(dfile)
        LSTrads = np.unique(uvd.lst_array * u.rad)
        LSThrs = aco.Angle(LSTrads).hour
        LSTindices = np.where(np.logical_and(LSThrs >= LSTrng[0], LSThrs <= LSTrng[-1]))[0]

        if LSTindices.size > 0:
            JDtimes = np.take(np.unique(uvd.time_array), LSTindices)
            files.append(dfile)
            times.append(JDtimes.tolist())

    # Loading in the correct data based on the provided LST range
    uvd = UVData()
#     uvd.read_uvh5(
#         files[0],
#         ant_str='cross',
#         times=times[0])
    uvd.read_miriad(
        files[0],
        ant_str='cross',
        time_range=[times[0][0], times[0][-1]])

    for file, time in zip(files[1:], times[1:]):
        uvdi = UVData()
#         uvdi.read_uvh5(
#             file, 
#             ant_str='cross',
#             times=time)
        uvd.read_miriad(
            file,
            ant_str='cross',
            time_range=[time[0], time[-1]])
        uvd += uvdi

    # Making new metadata
    UVD0 = UVData()
    UVDf = UVData()
#     UVD0.read_uvh5(files[0], read_data=False)
    UVD0.read_miriad_metadata(files[0])
#     UVDf.read_uvh5(files[-1], read_data=False)
    UVDf.read_miriad_metadata(files[-1])

    JDt0 = np.round(np.unique(UVD0.time_array)[0], 5)
    JDtf = np.round(np.unique(UVDf.time_array)[0], 5)
    JD = str(int(JDt0))
    JDt0 = '{:.5f}'.format(JDt0).split('.')[-1]
    JDtf = '{:.5f}'.format(JDtf).split('.')[-1]
    numfiles = len(files)

    # Saving new metadata
    uvd.extra_keywords['JDt0'] = JDt0
    uvd.extra_keywords['JDtf'] = JDtf
    uvd.extra_keywords['JD'] = JD
    uvd.extra_keywords['numfiles'] = numfiles
    uvd.extra_keywords['ext'] = ext
    uvd.extra_keywords['LSTrng'] = LSTrng
    uvd.extra_keywords['xants'] = xants
    
    # Naming new UVdata object
    hdf5 = 'zen.{JD}.{JDt0}_{JDtf}.{pol}.HH.hdf5.{ext}'.format(
        JD=JD,
        JDt0=JDt0,
        JDtf=JDtf,
        pol=pol,
        ext=ext)
    hdf5 = os.path.join(savepath, hdf5)
    print 'Writing:'
    print hdf5
    uvd.write_uvh5(hdf5, clobber=True)
# Out:
# yy
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.16694.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.17390.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.18086.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.18782.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.19478.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.20173.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.20869.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.21565.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.22261.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.22957.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.23653.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.24349.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.25045.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.25741.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.26437.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.27133.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.27829.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.28525.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.29221.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.29917.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.30613.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.31309.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.32004.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.32700.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.33396.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.34092.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.34788.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.35484.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.36180.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.36876.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.37572.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.38268.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.38964.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.39660.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.40356.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.41052.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.41748.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.42444.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.43140.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.43836.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.44531.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.45227.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.45923.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.46619.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.47315.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.48011.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.48707.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.49403.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.50099.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.50795.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.51491.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.52187.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.52883.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.53579.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.54275.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.54971.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.55667.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.56363.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.57058.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.57754.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.58450.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.59146.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.59842.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.60538.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.61234.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.61930.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.62626.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.63322.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.64018.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.64714.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.65410.yy.HH.uvcRP
# /data4/paper/HERA19Golden/RawData/2457548/zen.2457548.66106.yy.HH.uvcRP
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-fe394ed1c410> in <module>()
#      42             ant_str='cross',
#      43             time_range=[time[0], time[-1]])
# ---> 44         uvd += uvdi
#      45
#      46     # Making new metadata
#
# /home/fortino/anaconda3/envs/hera/lib/python2.7/site-packages/pyuvdata-1.2.1-py2.7-linux-x86_64.egg/pyuvdata/uvdata.pyc in __iadd__(self, other)
#     989             other: Another UVData object which will be added to self.
#     990         """
# --> 991         self.__add__(other, inplace=True)
#     992         return self
#     993
#
# /home/fortino/anaconda3/envs/hera/lib/python2.7/site-packages/pyuvdata-1.2.1-py2.7-linux-x86_64.egg/pyuvdata/uvdata.pyc in __add__(self, other, run_check, check_extra, run_check_acceptability, inplace)
#     789         if not isinstance(other, this.__class__):
#     790             raise ValueError('Only UVData objects can be added to a UVData object')
# --> 791         other.check(check_extra=check_extra, run_check_acceptability=run_check_acceptability)
#     792
#     793         # Check objects are compatible
#
# /home/fortino/anaconda3/envs/hera/lib/python2.7/site-packages/pyuvdata-1.2.1-py2.7-linux-x86_64.egg/pyuvdata/uvdata.pyc in check(self, check_extra, run_check_acceptability)
#     357
#     358         super(UVData, self).check(check_extra=check_extra,
# --> 359                                   run_check_acceptability=run_check_acceptability)
#     360
#     361         # Check internal consistency of numbers which don't explicitly correspond
#
# /home/fortino/anaconda3/envs/hera/lib/python2.7/site-packages/pyuvdata-1.2.1-py2.7-linux-x86_64.egg/pyuvdata/uvbase.pyc in check(self, check_extra, run_check_acceptability)
#     242                 if param.required is True:
#     243                     raise ValueError('Required UVParameter ' + p
# --> 244                                      + ' has not been set.')
#     245             else:
#     246                 # Check parameter shape
#
# ValueError: Required UVParameter _Nants_data has not been set.
